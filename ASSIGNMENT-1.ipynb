# %% [raw]
#                                                ASSIGNMENT-1

# %% [markdown]
#  Q1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [markdown]
# Answer:
#     Values: 'hello'/-87.8/6
#     Expressions: *,-,/,+

# %% [markdown]
#  Q2. What is the difference between string and variable?

# %% [markdown]
# Answer:
#         The difference between string and variable is that string can be written only in single or double code but variable  can be anything like integer,floating number or boolean numbers.In variable we can assign string also as a value.

# %% [markdown]
#  Q3. Describe three different data types.

# %% [markdown]
# Answer:
#     Different type of data types are:
#     1. string
#     2. list
#     3. dictionary
#     4. tuples

# %% [markdown]
#  Q4. What is an expressions made up of? what do all expressions do?

# %% [markdown]
# Answer:
#     An expression is a construct made up of variables, operators, and method invocations, which are constructed according to the syntax of the language, that evaluates to a single value.All expressions gives ua a single value after computing and evaluting the code or logic.

# %% [markdown]
#  Q5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# Answer:
#     Statement: Statements represent an action or command e.g print statements, assignment statements.
#
#     Expression: Expression is a combination of variables, operations and values that yields a result value

# %% [markdown]
#  Q6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %%
#Answer:
bacon = 22

# %%
bacon+1 
# when we add one with bacon which was assigned variable,
we will get 23 as a result.
# Out:
# 23

# %% [markdown]
#  Q7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %%
#Answer: in the first  cases it concatinate the'spam' and 
#in second case string is multiplied with and integer.
'spam'+ "spamspam"
# Out:
# 'spamspamspam'

# %%
'spam'*3
# Out:
# 'spamspamspam'

# %% [markdown]
#  Q8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Answer:
#     Eggs is a valid variable name and 100 is invalid because variable can not start with a number.

# %% [markdown]
#  Q9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# Answer: for integer = int()
#          for floating point = float()
#          for string = str()

# %% [markdown]
#  Q10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %%
#Answer:
# 'I have eaten ' + 99 + ' burritos.'
#when we will execute it,it will error bcoz we can not concatinate,
#an inetger with string
# Need to do forecastinh here,integer to string


'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
